# %%
import experiments

# %%
ode = "y''+y'/5+y+exp(-x/5)cos(x)/5=0, y(0)=0, y(1)=sin(1)/exp(0.2) on [0, 1]"
experiments1 = GridExperiments({
    "epochs": [2000],
    "N_f": [5000],
    "random_seed": [1, 2, 3],
    "init_lr": [1e-2, 2e-2, 3e-2, 5e-2]
})
print(f"ode: {ode}")
print(experiments1.get_tabular())
# Out:
# ode: y''+y'/5+y+exp(-x/5)cos(x)/5=0, y(0)=0, y(1)=sin(1)/exp(0.2) on [0, 1]
# ╒══════════╤═══════╤═══════════════╤═══════════╤═════════╤════════════╕
# │   epochs │   N_f │   random_seed │   init_lr │   done? │   min-loss │
# ╞══════════╪═══════╪═══════════════╪═══════════╪═════════╪════════════╡
# │     2000 │  5000 │             1 │      0.01 │       0 │   0.5362   │
# ├──────────┼───────┼───────────────┼───────────┼─────────┼────────────┤
# │     2000 │  5000 │             1 │      0.02 │       1 │   0.328485 │
# ├──────────┼───────┼───────────────┼───────────┼─────────┼────────────┤
# │     2000 │  5000 │             1 │      0.03 │       2 │   0.872156 │
# ├──────────┼───────┼───────────────┼───────────┼─────────┼────────────┤
# │     2000 │  5000 │             1 │      0.05 │       3 │   1.72667  │
# ├──────────┼───────┼───────────────┼───────────┼─────────┼────────────┤
# │     2000 │  5000 │             2 │      0.01 │       4 │   0.523449 │
# ...

# %%
ode = "y''+y'/5+y+exp(-x/5)cos(x)/5=0, y(0)=0, y(1)=sin(1)/exp(0.2) on [0, 1]"
experiments2 = GridExperiments({
    "init_lr": [2e-2],
    "random_seed": [3],
    "epochs": [1000, 2000, 3000, 4000, 5000, 7000, 9000, 10000],
    "N_f": [5000, 10000, 20000]
})
print(f"ode: {ode}")
print(experiments2.get_tabular())
# Out:
# ode: y''+y'/5+y+exp(-x/5)cos(x)/5=0, y(0)=0, y(1)=sin(1)/exp(0.2) on [0, 1]
# ╒═══════════╤═══════════════╤══════════╤═══════╤═════════╤════════════╕
# │   init_lr │   random_seed │   epochs │   N_f │   done? │   min-loss │
# ╞═══════════╪═══════════════╪══════════╪═══════╪═════════╪════════════╡
# │      0.02 │             3 │     1000 │  5000 │      18 │  0.538731  │
# ├───────────┼───────────────┼──────────┼───────┼─────────┼────────────┤
# │      0.02 │             3 │     1000 │ 10000 │      19 │  0.498352  │
# ├───────────┼───────────────┼──────────┼───────┼─────────┼────────────┤
# │      0.02 │             3 │     1000 │ 20000 │      20 │  0.535751  │
# ├───────────┼───────────────┼──────────┼───────┼─────────┼────────────┤
# │      0.02 │             3 │     2000 │  5000 │       9 │  0.286399  │
# ├───────────┼───────────────┼──────────┼───────┼─────────┼────────────┤
# │      0.02 │             3 │     2000 │ 10000 │      22 │  0.300233  │
# ...

# %%
ode = "y''+100y=0, y(0)=0, y'(0)=10 on [0, 1]"
experiments3 = GridExperiments({
    "epochs": [2000],
    "random_seed": [1, 2, 3, 4, 5],
    "N_f": [100, 500, 1000, 2000, 3000, 4000]
})
print(f"ode: {ode}")
print(experiments3.get_tabular())
# Out:
# ode: y''+100y=0, y(0)=0, y'(0)=10 on [0, 1]
# ╒══════════╤═══════════════╤═══════╤═════════╕
# │   epochs │   random_seed │   N_f │   done? │
# ╞══════════╪═══════════════╪═══════╪═════════╡
# │     2000 │             1 │   100 │      81 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             1 │   500 │      82 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             1 │  1000 │      83 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             1 │  2000 │      84 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             1 │  3000 │      85 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             1 │  4000 │      86 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             2 │   100 │      87 │
# ├──────────┼───────────────┼───────┼─────────┤
# │     2000 │             2 │   500 │      88 │
# ├──────────┼───────────────┼───────┼─────────┤
# ...

# %%
# Out:
# Updating f5bd39c..7013b54
# Fast-forward
#  README.md | 10 ++++++++++
#  upload.py | 37 +++++++++++++++++++++++++++++++++++++
#  2 files changed, 47 insertions(+)
#  create mode 100644 README.md
#  create mode 100644 upload.py
# From github.com:rprtr258/diploma-2021
#    f5bd39c..7013b54  master     -> origin/master
